# %%
import plotly.graph_objects as go
from IPython.display import display

def init_real_time_plot():
    # global fig_x, fig_y, fig_z
    global fig_y, fig_z

    # Initialize figures with two traces each: actual values and moving averages
    # fig_x = go.FigureWidget(data=[
    #     go.Scatter(x=[], y=[], mode='lines+markers', name='X Values'),
    #     go.Scatter(x=[], y=[], mode='lines', name='X Moving Avg', line=dict(color='red'))])
    fig_y = go.FigureWidget(data=[
        go.Scatter(x=[], y=[], mode='lines+markers', name='Y Values'),
        go.Scatter(x=[], y=[], mode='lines', name='Y Moving Avg', line=dict(color='red'))])
    fig_z = go.FigureWidget(data=[
        go.Scatter(x=[], y=[], mode='lines+markers', name='Z Values'),
        go.Scatter(x=[], y=[], mode='lines', name='Z Moving Avg', line=dict(color='red'))])

    # Set titles and display the figures
    # fig_x.update_layout(title_text='Real-Time X Values')
    fig_y.update_layout(title_text='Real-Time Y1 Values')
    fig_z.update_layout(title_text='Real-Time Y3 Values')
    # display(fig_x, fig_y, fig_z)
    display(fig_y, fig_z)

# %%
def send_alert_to_microbit(serial_connection, message):
    """
    Sends an alert message to the microbit via the serial connection.

    Args:
    - serial_connection: The open serial connection to the microbit.
    - message: The message to send as a string.
    """
    serial_connection.write(message.encode())
    # serial_connection.close()

# %%
import serial
import time
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def read_serial_data(port, baud_rate=115200, timeout=1, duration=10):
    
    global ser
    init_real_time_plot()  # Ensure you have initialized a Plotly FigureWidget globally
    ser = serial.Serial(port, baud_rate, timeout=timeout)
    end_time = time.time() + duration
    value_index = 0  # Cycle through 0 (x), 1 (y), 2 (z)
    sample_index = 0  # Increment for each new set of x, y, z values

    lst_y1 = []
    lst_y3 = []
    try:
        while True: # if want to read data continuously
        # while time.time() < end_time:  # Continuously read and plot data
            if ser.in_waiting > 0:
                data = ser.readline().decode('utf-8').strip()
                if data:
                    try:
                        value = int(data)
                        print(data,value)
                        # Determine which plot to update based on value_index
                        # if value_index == 0:  # X value
                        #     add_data_to_plot(ser, value, None, None, sample_index)
                        # elif value_index == 1:  # Y value
                        #     add_data_to_plot(ser, None, value, None, sample_index)
                        
                        if value_index == 0:  # X value                                
                            # add_data_to_plot(ser, None, value, None, sample_index)
                            lst_y1.append(value)
                        elif value_index == 1:  # Y value
                            # add_data_to_plot(ser, None, None, value, sample_index)
                        # elif value_index == 2:  # Z value
                        #     add_data_to_plot(ser, None, None, value, sample_index)
                            lst_y3.append(value)
                            # sample_index += 1  # Increment sample_index after a full cycle
                        
                        value_index = (value_index + 1) % 2  # Cycle through 0, 1, 2
                    except ValueError:
                        pass  # Ignore non-integer values
                time.sleep(0.01)  # Adjust based on your data rate
                if len(lst_y1)>0 and len(lst_y3)>0:
                    if lst_y1[-1] <-960 and lst_y3[-1]<-960:
                        send_alert_to_microbit(ser, "Alertttt")
                    
    finally:
        ser.close()

# %%
import serial
import time
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def read_serial_data(port, baud_rate=115200, timeout=1, duration=10):
    
    global ser
    init_real_time_plot()  # Ensure you have initialized a Plotly FigureWidget globally
    ser = serial.Serial(port, baud_rate, timeout=timeout)
    end_time = time.time() + duration
    value_index = 0  # Cycle through 0 (x), 1 (y), 2 (z)
    sample_index = 0  # Increment for each new set of x, y, z values

    lst_y1 = []
    lst_y3 = []
    try:
        while True: # if want to read data continuously
        # while time.time() < end_time:  # Continuously read and plot data
            if ser.in_waiting > 0:
                data = ser.readline().decode('utf-8').strip()
                if data:
                    try:
                        value = int(data)
                        # print(data,value)
                        # Determine which plot to update based on value_index
                        # if value_index == 0:  # X value
                        #     add_data_to_plot(ser, value, None, None, sample_index)
                        # elif value_index == 1:  # Y value
                        #     add_data_to_plot(ser, None, value, None, sample_index)
                        
                        if value_index == 0:  # X value                                
                            add_data_to_plot(ser, None, value, None, sample_index)
                        elif value_index == 1:  # Y value
                            add_data_to_plot(ser, None, None, value, sample_index)
                        # elif value_index == 2:  # Z value
                        #     add_data_to_plot(ser, None, None, value, sample_index)
                            sample_index += 1  # Increment sample_index after a full cycle
                        
                        value_index = (value_index + 1) % 2  # Cycle through 0, 1, 2
                    except ValueError:
                        pass  # Ignore non-integer values
                time.sleep(0.001)  # Adjust based on your data rate
                # if len(lst_y1)>0 and len(lst_y3)>0:
                #     if lst_y1[-1] <-960 and lst_y3[-1]<-960:
                #         send_alert_to_microbit(ser, "Alertttt")
                    
    finally:
        ser.close()

# %%
# Define window size for the moving average
N = 1 # Example window size
# Initialize rolling windows for x, y, z values
rolling_window_x, rolling_window_y, rolling_window_z = [], [], []

THRESHOLD_X = -150
THRESHOLD_Y = -960
THRESHOLD_Z = -900
data = {
    'x': [],
    'y': [],
    'z': [],
    'x_moving_avg': [],
    'y_moving_avg': [],
    'z_moving_avg': []
}

def add_data_to_plot(serial_connection, x_new, y_new, z_new, sample_index):
    resp = ''
    # global rolling_window_x, rolling_window_y, rolling_window_z
    global rolling_window_y, rolling_window_z

    
    # Update and calculate moving average for X values, check threshold
    # if x_new is not None:
    #     rolling_window_x.append(x_new)
    #     rolling_window_x = rolling_window_x[-N:]
    #     x_moving_avg = sum(rolling_window_x) / len(rolling_window_x)
        
        
        
    #     with fig_x.batch_update():
    #         fig_x.data[0].x += (sample_index,)
    #         fig_x.data[0].y += (x_new,)
    #         fig_x.data[1].x += (sample_index,)
    #         fig_x.data[1].y += (x_moving_avg,)
        
    #     if x_moving_avg > THRESHOLD_X:
    #         # print('alertx')
    #         send_alert_to_microbit(serial_connection, "Alert X")

    # Repeat the process for Y and Z values
    if y_new is not None:
        rolling_window_y.append(y_new)
        rolling_window_y = rolling_window_y[-N:]
        y_moving_avg = sum(rolling_window_y) / len(rolling_window_y)
        
        with fig_y.batch_update():
            fig_y.data[0].x += (sample_index,)
            fig_y.data[0].y += (y_new,)
            # fig_y.data[1].x += (sample_index,)
            # fig_y.data[1].y += (y_moving_avg,)
            
        # if rolling_window_y[-1] < THRESHOLD_Y:
            
        # if y_new < THRESHOLD_Y:
        #     # print('alerty')
        #     send_alert_to_microbit(serial_connection, "Alert Y")
            
    if z_new is not None:
        rolling_window_z.append(z_new)
        rolling_window_z = rolling_window_z[-N:]
        # z_moving_avg = sum(rolling_window_z) / len(rolling_window_z)
        z_moving_avg = sum(rolling_window_z) / len(rolling_window_z)
        
        with fig_z.batch_update():
            fig_z.data[0].x += (sample_index,)
            fig_z.data[0].y += (z_new,)
            # fig_z.data[1].x += (sample_index,)
            # fig_z.data[1].y += (z_moving_avg,)
        
        
        # if z_new < THRESHOLD_Z:
        #     # print('alertz')
        #     send_alert_to_microbit(serial_connection, "Alert Z")

    #if rolling_window_y[-1] < THRESHOLD_Y and sum(rolling_window_y[-10:])/10 > -800 and sum(rolling_window_z[-10:])/10 < THRESHOLD_Z:
    #    print('test')
    #    send_alert_to_microbit(ser, "Alertttt")

        
    if rolling_window_y[-1] < THRESHOLD_Y and sum(rolling_window_y[-10:])/10 > 300:
        print('test')
        send_alert_to_microbit(serial_connection, "Alertttt")
# Out:
#   File <tokenize>:83
#     send_alert_to_microbit(ser, "Alertttt")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
port = '/dev/tty.usbmodem21202'  # Example for Linux/Mac. Use 'COM#' for Windows.
read_serial_data(port, duration=15)  # Read data for 10 seconds
# Out:
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Y Values',
#               'type': 'scatter',
#               'uid': 'd8973b96-513a-4d68-9ed2-17cbdf67a1ad',
#               'x': [],
#               'y': []},
#              {'line': {'color': 'red'},
#               'mode': 'lines',
#               'name': 'Y Moving Avg',
#               'type': 'scatter',
#               'uid': 'e59c9e9a-4cbf-4315-b1b0-b46b7bbea621',
#               'x': [],
#               'y': []}],
#     'layout': {'template': '...', 'title': {'text': 'Real-Time Y1 Values'}}
# })
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Z Values',
#               'type': 'scatter',
#               'uid': '0a6b84cf-9904-463a-a69e-02200d178b8a',
#               'x': [],
#               'y': []},
#              {'line': {'color': 'red'},
#               'mode': 'lines',
#               'name': 'Z Moving Avg',
#               'type': 'scatter',
#               'uid': '1a68d61a-f91e-452d-a454-c6573e27adae',
#               'x': [],
#               'y': []}],
#     'layout': {'template': '...', 'title': {'text': 'Real-Time Y3 Values'}}
# })
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 2
#       1 port = '/dev/tty.usbmodem21202'  # Example for Linux/Mac. Use 'COM#' for Windows.
# ----> 2 read_serial_data(port, duration=15)  # Read data for 10 seconds
#
# Cell In[22], line 35, in read_serial_data(port, baud_rate, timeout, duration)
#      33     add_data_to_plot(ser, None, value, None, sample_index)
#      34 elif value_index == 1:  # Y value
# ---> 35     add_data_to_plot(ser, None, None, value, sample_index)
#      36 # elif value_index == 2:  # Z value
#      37 #     add_data_to_plot(ser, None, None, value, sample_index)
#      38     sample_index += 1  # Increment sample_index after a full cycle
#
# Cell In[36], line 68, in add_data_to_plot(serial_connection, x_new, y_new, z_new, sample_index)
#      66     with fig_z.batch_update():
#      67         fig_z.data[0].x += (sample_index,)
# ---> 68         fig_z.data[0].y += (z_new,)
#      69         # fig_z.data[1].x += (sample_index,)
#      70         # fig_z.data[1].y += (z_moving_avg,)
#      71
#    (...)
#      74     #     # print('alertz')
#      75     #     send_alert_to_microbit(serial_connection, "Alert Z")
#      77 if rolling_window_y[-1] < THRESHOLD_Y and sum(rolling_window_y[-10:])/10 > -800 and sum(rolling_window_z[-10:])/10 < THRESHOLD_Z:
#
# File /opt/anaconda3/lib/python3.8/contextlib.py:120, in _GeneratorContextManager.__exit__(self, type, value, traceback)
#     118 if type is None:
#     119     try:
# --> 120         next(self.gen)
#     121     except StopIteration:
#     122         return False
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/basedatatypes.py:3062, in BaseFigure.batch_update(self)
#    3055 (
#    3056     restyle_data,
#    3057     relayout_data,
#    3058     trace_indexes,
#    3059 ) = self._build_update_params_from_batch()
#    3061 # ### Call plotly_update ###
# -> 3062 self.plotly_update(
#    3063     restyle_data=restyle_data,
#    3064     relayout_data=relayout_data,
#    3065     trace_indexes=trace_indexes,
#    3066 )
#    3068 # ### Clear out saved batch edits ###
#    3069 self._batch_layout_edits.clear()
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/basedatatypes.py:2925, in BaseFigure.plotly_update(self, restyle_data, relayout_data, trace_indexes, **kwargs)
#    2921 # Send update message
#    2922 # -------------------
#    2923 # Send a plotly_update message to the frontend (if any)
#    2924 if restyle_changes or relayout_changes:
# -> 2925     self._send_update_msg(
#    2926         restyle_data=restyle_changes,
#    2927         relayout_data=relayout_changes,
#    2928         trace_indexes=trace_indexes,
#    2929         **msg_kwargs,
#    2930     )
#    2932 # Dispatch changes
#    2933 # ----------------
#    2934 # ### Dispatch restyle changes ###
#    2935 if restyle_changes:
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/basewidget.py:335, in BaseFigureWidget._send_update_msg(self, restyle_data, relayout_data, trace_indexes, source_view_id)
#     324 update_msg = {
#     325     "style_data": restyle_data,
#     326     "layout_data": relayout_data,
#    (...)
#     330     "source_view_id": source_view_id,
#     331 }
#     333 # Send message
#     334 # ------------
# --> 335 self._py2js_update = update_msg
#     336 self._py2js_update = None
#
# File /opt/anaconda3/lib/python3.8/site-packages/plotly/basedatatypes.py:717, in BaseFigure.__setattr__(self, prop, value)
#     704 """
#     705 Parameters
#     706 ----------
#    (...)
#     713 None
#     714 """
#     715 if prop.startswith("_") or hasattr(self, prop):
#     716     # Let known properties and private properties through
# --> 717     super(BaseFigure, self).__setattr__(prop, value)
#     718 else:
#     719     # Raise error on unknown public properties
#     720     raise AttributeError(prop)
#
# File /opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py:748, in TraitType.__set__(self, obj, value)
#     746     raise TraitError('The "%s" trait is read-only.' % self.name)
#     747 else:
# --> 748     self.set(obj, value)
#
# File /opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py:737, in TraitType.set(self, obj, value)
#     733     silent = False
#     734 if silent is not True:
#     735     # we explicitly compare silent to True just in case the equality
#     736     # comparison above returns something other than True/False
# --> 737     obj._notify_trait(self.name, old_value, new_value)
#
# File /opt/anaconda3/lib/python3.8/site-packages/traitlets/traitlets.py:1532, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1531 def _notify_trait(self, name, old_value, new_value):
# -> 1532     self.notify_change(
#    1533         Bunch(
#    1534             name=name,
#    1535             old=old_value,
#    1536             new=new_value,
#    1537             owner=self,
#    1538             type="change",
#    1539         )
#    1540     )
#
# File /opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:605, in Widget.notify_change(self, change)
#     601 if self.comm is not None and self.comm.kernel is not None:
#     602     # Make sure this isn't information that the front-end just sent us.
#     603     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     604         # Send new state to front-end
# --> 605         self.send_state(key=name)
#     606 super(Widget, self).notify_change(change)
#
# File /opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:489, in Widget.send_state(self, key)
#     487 state, buffer_paths, buffers = _remove_buffers(state)
#     488 msg = {'method': 'update', 'state': state, 'buffer_paths': buffer_paths}
# --> 489 self._send(msg, buffers=buffers)
#
# File /opt/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:737, in Widget._send(self, msg, buffers)
#     735 """Sends a message to the model in the front-end."""
#     736 if self.comm is not None and self.comm.kernel is not None:
# --> 737     self.comm.send(data=msg, buffers=buffers)
#
# File /opt/anaconda3/lib/python3.8/site-packages/comm/base_comm.py:113, in BaseComm.send(self, data, metadata, buffers)
#     111 def send(self, data=None, metadata=None, buffers=None):
#     112     """Send a message to the frontend-side version of this comm"""
# --> 113     self.publish_msg(
#     114         "comm_msg",
#     115         data=data,
#     116         metadata=metadata,
#     117         buffers=buffers,
#     118     )
#
# File /opt/anaconda3/lib/python3.8/site-packages/ipykernel/comm/comm.py:31, in BaseComm.publish_msg(self, msg_type, data, metadata, buffers, **keys)
#      29 data = {} if data is None else data
#      30 metadata = {} if metadata is None else metadata
# ---> 31 content = json_clean(dict(data=data, comm_id=self.comm_id, **keys))
#      33 if self.kernel is None:
#      34     self.kernel = Kernel.instance()
#
# File /opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py:157, in json_clean(obj)
#     155     out = {}
#     156     for k, v in obj.items():
# --> 157         out[str(k)] = json_clean(v)
#     158     return out
#     159 if isinstance(obj, (datetime, date)):
#
# File /opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py:157, in json_clean(obj)
#     155     out = {}
#     156     for k, v in obj.items():
# --> 157         out[str(k)] = json_clean(v)
#     158     return out
#     159 if isinstance(obj, (datetime, date)):
#
#     [... skipping similar frames: json_clean at line 157 (2 times)]
#
# File /opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py:157, in json_clean(obj)
#     155     out = {}
#     156     for k, v in obj.items():
# --> 157         out[str(k)] = json_clean(v)
#     158     return out
#     159 if isinstance(obj, (datetime, date)):
#
# File /opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py:140, in json_clean(obj)
#     137     obj = list(obj)
#     139 if isinstance(obj, list):
# --> 140     return [json_clean(x) for x in obj]
#     142 if isinstance(obj, dict):
#     143     # First, validate that the dict won't lose data in conversion due to
#     144     # key collisions after stringification.  This can happen with keys like
#     145     # True and 'true' or 1 and '1', which collide in JSON.
#     146     nkeys = len(obj)
#
# File /opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py:140, in <listcomp>(.0)
#     137     obj = list(obj)
#     139 if isinstance(obj, list):
# --> 140     return [json_clean(x) for x in obj]
#     142 if isinstance(obj, dict):
#     143     # First, validate that the dict won't lose data in conversion due to
#     144     # key collisions after stringification.  This can happen with keys like
#     145     # True and 'true' or 1 and '1', which collide in JSON.
#     146     nkeys = len(obj)
#
# File /opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py:140, in json_clean(obj)
#     137     obj = list(obj)
#     139 if isinstance(obj, list):
# --> 140     return [json_clean(x) for x in obj]
#     142 if isinstance(obj, dict):
#     143     # First, validate that the dict won't lose data in conversion due to
#     144     # key collisions after stringification.  This can happen with keys like
#     145     # True and 'true' or 1 and '1', which collide in JSON.
#     146     nkeys = len(obj)
#
# File /opt/anaconda3/lib/python3.8/site-packages/ipykernel/jsonutil.py:140, in <listcomp>(.0)
#     137     obj = list(obj)
#     139 if isinstance(obj, list):
# --> 140     return [json_clean(x) for x in obj]
#     142 if isinstance(obj, dict):
#     143     # First, validate that the dict won't lose data in conversion due to
#     144     # key collisions after stringification.  This can happen with keys like
#     145     # True and 'true' or 1 and '1', which collide in JSON.
#     146     nkeys = len(obj)
#
# KeyboardInterrupt:
